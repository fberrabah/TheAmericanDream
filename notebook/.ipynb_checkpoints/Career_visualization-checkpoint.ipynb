# %%
import pandas as pd
import sqlalchemy
import mysql.connector
import matplotlib as mpl    
import matplotlib.pyplot as plt
import seaborn as sns
#Pour que python reconnaisse un dossier comme un module il faut ajouter en son sein un fichier __init__.py 
#et également l'ajouter au PATH

import sys  

sys.path.insert(0, "/home/apprenant/Desktop/AmericanDream/")


#On peut ensuite importer le dossier comme un module

from src.d00_utils.mysql_utils import mysql_connect, save_to_mysql
connect = mysql_connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8a0999f55bc2> in <module>
#       2 import sqlalchemy
#       3 import mysql.connector
# ----> 4 import matplotlib as mpl
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data = pd.read_sql("Analyst_01_v1.0",con=connect)
data2 = pd.read_sql("Salary_01_v1.0",con=connect)

# %%
data2.head()
# Out:
#    level_0  index  SalaryUSD        Country PostalCode    EmploymentStatus  \
# 0        0      0   115000.0  United States         03  Full time employee
# 1        1      1   100000.0  United States       None  Full time employee
# 2        2      2   100000.0          Spain      28046  Full time employee
# 3        3      3    70000.0  United States      94133  Full time employee
# 4        4      4   110000.0  United States      95354  Full time employee
#
#                                             JobTitle ManageStaff  \
# 0  DBA (Production Focus - build & troubleshoot s...          No
# 1                  Developer: App code (C#, JS, etc)          No
# 2                                              Other         Yes
# 3                                            Analyst          No
# 4  DBA (General - splits time evenly between writ...          No
#
#    YearsWithThisTypeOfJob                                   HowManyCompanies  \
# 0                       5  1 (this is the only company where I've had thi...
# 1                       6  1 (this is the only company where I've had thi...
# 2                       3  1 (this is the only company where I've had thi...
# 3                       3  1 (this is the only company where I've had thi...
# 4                      25                                                  3
#
#   OtherPeopleOnYourTeam CompanyEmployeesOverall  \
# 0                     2               Not Asked
# 1           More than 5               Not Asked
# 2                     1               Not Asked
# 3                     2               Not Asked
# 4                  None               Not Asked
#
#   PopulationOfLargestCityWithin20Miles  EmploymentSector LookingForAnotherJob  \
# 0                 20K-99K (large town)  Private business            Not Asked
# 1                     1M+ (metropolis)  Private business            Not Asked
# 2                     1M+ (metropolis)  Private business            Not Asked
# 3                     1M+ (metropolis)  Private business            Not Asked
# 4                     100K-299K (city)        Non-profit            Not Asked
#
#                       CareerPlansThisYear Gender OtherJobDuties
# 0  Stay with the same employer, same role   Male      Not Asked
# 1                       Prefer not to say   Male      Not Asked
# 2  Stay with the same employer, same role   Male      Not Asked
# 3         Change both employers and roles   Male      Not Asked
# 4  Stay with the same employer, same role   Male      Not Asked

# %%
# Out:
#       level_0  index  SalaryUSD         Country PostalCode  \
# 8622     8622   8622    35000.0          France  Not Asked
# 8623     8623   8623    56000.0  United Kingdom  Not Asked
# 8624     8624   8624    95000.0         Germany  Not Asked
# 8625     8625   8625    61515.0  United Kingdom  Not Asked
# 8626     8626   8626   200000.0   United States  Not Asked
#
#                                        EmploymentStatus JobTitle ManageStaff  \
# 8622  Full time employee of a consulting/contracting...      DBA          No
# 8623                                 Full time employee      DBA          No
# 8624                                 Full time employee    Other         Yes
# 8625                                 Full time employee      DBA          No
# 8626                                 Full time employee      DBA          No
#
#       YearsWithThisTypeOfJob HowManyCompanies OtherPeopleOnYourTeam  \
# 8622                      10        Not Asked                  None
# 8623                       2        Not Asked                  None
# 8624                      25        Not Asked                     2
# 8625                       3        Not Asked                     1
# 8626                       5        Not Asked                     2
#
#      CompanyEmployeesOverall PopulationOfLargestCityWithin20Miles  \
# 8622               Not Asked                            Not Asked
# 8623               Not Asked                            Not Asked
# 8624               Not Asked                            Not Asked
# 8625               Not Asked                            Not Asked
# 8626               Not Asked                            Not Asked
#
#       EmploymentSector                    LookingForAnotherJob  \
# 8622  Private business  Yes, but only passively (just curious)
# 8623  Private business  Yes, but only passively (just curious)
# 8624  Private business  Yes, but only passively (just curious)
# 8625  Private business                                      No
# 8626  Private business  Yes, but only passively (just curious)
#
#      CareerPlansThisYear     Gender OtherJobDuties
# 8622           Not Asked  Not Asked      Not Asked
# 8623           Not Asked  Not Asked      Not Asked
# 8624           Not Asked  Not Asked      Not Asked
# 8625           Not Asked  Not Asked      Not Asked
# 8626           Not Asked  Not Asked      Not Asked

# %%
plt.figure(figsize = (15,10))
ax = plt.boxplot(data2["SalaryUSD"], whis=[5,95], vert=False)
plt.show()

# %%
plt.figure(figsize=(15, 12))

sns.barplot(x=data2['SalaryUSD'], y=data2.index)

plt.xlabel("")

plt.title("Salaire moyen")

# %%
plt.figure(figsize=(15, 12))

sns.barplot(x=data2['SalaryUSD'], y=data2.index)

plt.xlabel("")

plt.title("Salaire moyen")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-726c84654904> in <module>
#       3 plt.title("salaire moyen")
#       4
# ----> 5 sns.heatmap(data=data2, annot=True)
#       6
#       7 plt.xlabel("SalaryUSD")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     546                           annot_kws, cbar, cbar_kws, xticklabels,
#     547                           yticklabels, mask)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     163
#     164         # Determine good default values for the colormapping
# --> 165         self._determine_cmap_params(plot_data, vmin, vmax,
#     166                                     cmap, center, robust)
#     167
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     197
#     198         # plot_data is a np.ma.array instance
# --> 199         calc_data = plot_data.astype(float).filled(np.nan)
#     200         if vmin is None:
#     201             if robust:
#
# ValueError: could not convert string to float: 'United States'

# %%
plt.figure(figsize=(14,7))

plt.title("salaire moyen")

sns.heatmap(data=data2, annot=True)

plt.xlabel("SalaryUSD")

# %%
sns.regplot(x=data2['USA'], y=data2['SalaryUSD'])
